# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
import skimage
import csv

# %%
img = cv2.imread("13.jpg");
cv2.threshold(img, img, 127, 255, cv2.THRESH_BINARY); 
cv2.Mat_skel(img.size(), CV_8UC1, cv2.Scalar(0));
cv2.Mat_temp;
cv2.Mat_eroded;
cv2.Mat_element = cv2.getStructuringElement(cv2.MORPH_CROSS, cv2.Size(3, 3));

do
{
  cv2.erode(img, eroded, element);
  cv2.dilate(eroded, temp, element); // temp = open(img)
  cv2.subtract(img, temp, temp);
  cv2.bitwise_or(skel, temp, skel);
  eroded.copyTo(img);
 
  done = (cv2.countNonZero(img) == 0);
} while();
# Out:
#   File "<ipython-input-29-386869c96a97>", line 10
#     cv2.erode(img, eroded, element);
#                                    ^
# SyntaxError: invalid syntax

# %%
import cv2
import numpy as np

img = cv2.imread("13.jpg");
'''# Create an image with text on it
img2 = np.zeros((500,500),dtype='uint8')
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img2,img1,(5,70), font, 2,(255),5,cv2.LINE_AA)
img3 = img.copy()'''

# Structuring Element
kernel = cv2.getStructuringElement(cv2.MORPH_CROSS,(3,3))
# Create an empty output image to hold values
thin = np.zeros(img.shape,dtype='uint8')

# Loop until erosion leads to an empty set
while(True):
    # Erosion
    erode = cv2.erode(img,kernel)
    # Opening on eroded image
    opening = cv2.morphologyEx(erode,cv2.MORPH_OPEN,kernel)
    # Subtract these two
    subset = erode - opening
    # Union of all previous sets
    thin = cv2.bitwise_or(subset,thin)
    # Set the eroded image for next iteration
    img = erode.copy()
    
cv2.imshow('original',img)
cv2.imshow('thinned',thin)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-5c482f5cfd30> in <module>
#      19     erode = cv2.erode(img,kernel)
#      20     # Opening on eroded image
# ---> 21     opening = cv2.morphologyEx(erode,cv2.MORPH_OPEN,kernel)
#      22     # Subtract these two
#      23     subset = erode - opening
#
# KeyboardInterrupt:

# %%
from skimage import img_as_float
from skimage import io, color, morphology
import matplotlib.pyplot as plt

image = img_as_float(color.rgb2gray(io.imread('13.jpg')))
image_binary = image < 0.5
out_skeletonize = morphology.skeletonize(image_binary)
out_thin = morphology.thin(image_binary)


f, (ax0, ax1, ax2) = plt.subplots(1, 3, figsize=(10, 3))

ax0.imshow(image, cmap='gray')
ax0.set_title('Input')

ax1.imshow(out_skeletonize, cmap='gray')
ax1.set_title('Skeletonize')

ax2.imshow(out_thin, cmap='gray')
ax2.set_title('Thin')

#plt.savefig('/tmp/char_out.png')
plt.show()
